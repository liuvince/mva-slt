# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/neccam/slt.git

# %cd slt

# !chmod +x data/download.sh
# !data/download.sh

# !cp ../drive/MyDrive/slt/requirements.txt requirements.txt

# !pip -q install -r requirements.txt
# Out:
# Mounted at /content/drive
# Cloning into 'slt'...
# remote: Enumerating objects: 99, done.
# remote: Total 99 (delta 0), reused 0 (delta 0), pack-reused 99
# Unpacking objects: 100% (99/99), done.
# /content/slt
# --2021-01-04 15:39:14--  http://cihancamgoz.com/files/cvpr2020/phoenix14t.pami0.train
# Resolving cihancamgoz.com (cihancamgoz.com)... 192.232.218.145
# Connecting to cihancamgoz.com (cihancamgoz.com)|192.232.218.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935289362 (1.8G)
# Saving to: ‘phoenix14t.pami0.train’
#
# phoenix14t.pami0.tr 100%[===================>]   1.80G  19.7MB/s    in 99s
#
# 2021-01-04 15:40:54 (18.6 MB/s) - ‘phoenix14t.pami0.train’ saved [1935289362/1935289362]
#
# --2021-01-04 15:40:54--  http://cihancamgoz.com/files/cvpr2020/phoenix14t.pami0.dev
# Resolving cihancamgoz.com (cihancamgoz.com)... 192.232.218.145
# Connecting to cihancamgoz.com (cihancamgoz.com)|192.232.218.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130831227 (125M)
# Saving to: ‘phoenix14t.pami0.dev’
#
# phoenix14t.pami0.de 100%[===================>] 124.77M  20.4MB/s    in 7.1s
#
# 2021-01-04 15:41:01 (17.7 MB/s) - ‘phoenix14t.pami0.dev’ saved [130831227/130831227]
#
# --2021-01-04 15:41:01--  http://cihancamgoz.com/files/cvpr2020/phoenix14t.pami0.test
# Resolving cihancamgoz.com (cihancamgoz.com)... 192.232.218.145
# Connecting to cihancamgoz.com (cihancamgoz.com)|192.232.218.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151327204 (144M)
# Saving to: ‘phoenix14t.pami0.test’
#
# phoenix14t.pami0.te 100%[===================>] 144.32M  21.0MB/s    in 7.7s
#
# 2021-01-04 15:41:10 (18.6 MB/s) - ‘phoenix14t.pami0.test’ saved [151327204/151327204]
#
#      |████████████████████████████████| 112kB 14.4MB/s
#      |████████████████████████████████| 112kB 23.0MB/s
#      |████████████████████████████████| 163kB 22.8MB/s
#      |████████████████████████████████| 399kB 28.9MB/s
#      |████████████████████████████████| 2.3MB 34.8MB/s
#      |████████████████████████████████| 81kB 9.0MB/s
#      |████████████████████████████████| 61kB 8.6MB/s
#      |████████████████████████████████| 2.4MB 57.5MB/s
#      |████████████████████████████████| 61kB 8.2MB/s
#      |████████████████████████████████| 296kB 50.7MB/s
#      |████████████████████████████████| 51kB 7.2MB/s
#      |████████████████████████████████| 51kB 7.6MB/s
#      |████████████████████████████████| 61kB 8.5MB/s
#      |████████████████████████████████| 92kB 10.9MB/s
#      |████████████████████████████████| 92kB 11.5MB/s
#      |████████████████████████████████| 13.1MB 45.5MB/s
#      |████████████████████████████████| 51kB 7.4MB/s
#      |████████████████████████████████| 20.2MB 1.3MB/s
#      |████████████████████████████████| 28.2MB 1.4MB/s
#      |████████████████████████████████| 71kB 8.6MB/s
#      |████████████████████████████████| 10.0MB 27.9MB/s
#      |████████████████████████████████| 2.1MB 25.2MB/s
#      |████████████████████████████████| 7.1MB 25.7MB/s
#      |████████████████████████████████| 1.3MB 42.2MB/s
#      |████████████████████████████████| 92kB 11.0MB/s
#      |████████████████████████████████| 71kB 9.2MB/s
#      |████████████████████████████████| 163kB 54.0MB/s
#      |████████████████████████████████| 61kB 7.5MB/s
#      |████████████████████████████████| 71kB 8.5MB/s
#      |████████████████████████████████| 256kB 51.8MB/s
#      |████████████████████████████████| 512kB 55.8MB/s
#      |████████████████████████████████| 276kB 64.8MB/s
#      |████████████████████████████████| 61kB 8.0MB/s
#      |████████████████████████████████| 665kB 57.2MB/s
#      |████████████████████████████████| 1.0MB 43.9MB/s
#      |████████████████████████████████| 753.4MB 19kB/s
#      |████████████████████████████████| 81kB 9.8MB/s
#      |████████████████████████████████| 4.0MB 58.3MB/s
#      |████████████████████████████████| 61kB 8.5MB/s
#      |████████████████████████████████| 133kB 64.8MB/s
#      |████████████████████████████████| 327kB 67.8MB/s
#   Building wheel for absl-py (setup.py) ... done
#   Building wheel for gast (setup.py) ... done
#   Building wheel for opt-einsum (setup.py) ... done
#   Building wheel for pycosat (setup.py) ... done
#   Building wheel for pycparser (setup.py) ... done
#   Building wheel for PyYAML (setup.py) ... done
#   Building wheel for wrapt (setup.py) ... done
# ERROR: tensorflow 2.4.0 has requirement absl-py~=0.10, but you'll have absl-py 0.9.0 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement google-pasta~=0.2, but you'll have google-pasta 0.1.8 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement grpcio~=1.32.0, but you'll have grpcio 1.26.0 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement keras-preprocessing~=1.1.2, but you'll have keras-preprocessing 1.1.0 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement numpy~=1.19.2, but you'll have numpy 1.18.1 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement opt-einsum~=3.3.0, but you'll have opt-einsum 3.1.0 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement six~=1.15.0, but you'll have six 1.13.0 which is incompatible.
# ERROR: tensorflow 2.4.0 has requirement wrapt~=1.12.1, but you'll have wrapt 1.11.2 which is incompatible.
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.17.2, but you'll have google-auth 1.10.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.1.0; python_version >= "3.0", but you'll have pandas 1.0.3 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.15.0, but you'll have six 1.13.0 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement pandas>=1.0.4, but you'll have pandas 1.0.3 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
# !cp ../drive/MyDrive/slt/late-fusion-duo/*.py signjoey/

# %%
# !mkdir data/PHOENIX2014T 

# !mv phoenix14t.pami0.dev data/PHOENIX2014T 
# !mv phoenix14t.pami0.test data/PHOENIX2014T 
# !mv phoenix14t.pami0.train data/PHOENIX2014T

# !unzip -q ../drive/MyDrive/slt/keypoints/dev_features.zip -d data
# !unzip -q ../drive/MyDrive/slt/keypoints/train_features.zip -d data
# !unzip -q ../drive/MyDrive/slt/keypoints/test_features.zip -d data

# %%
from six.moves import cPickle
import gzip
import torch
import os
import numpy as np
from tqdm import tqdm
import pickle

wd='data'

def load_dataset_file(filename):
    with gzip.open(filename, "rb") as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %% [markdown]
# ## Hidden features

# %%
for s in ['dev', 'test', 'train']:
  filename = "data/PHOENIX2014T/phoenix14t.pami0.{}".format(s)
  dst_filename = "data/PHOENIX2014T/phoenix14t.pami1.{}".format(s)

  src_features = load_dataset_file(filename)

  for src in tqdm(src_features):
    name = os.path.basename(src['name']) + '.npy'

    dst = os.path.join(wd, os.path.join(s, name))
    
    new_features = np.load(dst)
    src['sign'] = torch.Tensor(new_features)

  with gzip.open(dst_filename, "wb") as f:
    pickle.dump(src_features, f)
# Out:
# 100%|██████████| 519/519 [00:06<00:00, 77.29it/s]
# 100%|██████████| 642/642 [00:00<00:00, 1197.78it/s]
# 100%|██████████| 7096/7096 [01:17<00:00, 91.02it/s]

# %% [markdown]
# ## Change config files

# %%
import yaml
with open("configs/sign.yaml") as f:
     list_doc = yaml.load(f)

for s in ['train', 'test', 'dev']:
  list_doc['data'][s] = ['PHOENIX2014T/phoenix14t.pami{}.{}'.format(i, s) for i in range(2)]

list_doc['data']['feature_size'] = [1024, 1024]

with open("configs/sign.yaml", "w") as f:
    yaml.dump(list_doc, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Run

# %%
# !cp -r '../drive/MyDrive/slt/models/baseline_1' baseline
# !cp -r '../drive/MyDrive/slt/models/hidden_features_1' features

# %%
import os
import sys
from signjoey.prediction import test

test(cfg_file="configs/sign.yaml", ckpts=["baseline/best.ckpt", "features/best.ckpt"], output_path="")
# Out:
# 2021-01-04 15:57:26,188 - ------------------------------------------------------------
# 2021-01-04 15:57:26,192 - [DEV] partition [RECOGNITION] experiment [BW]: 1
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py:359: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   var = torch.tensor(arr, dtype=self.dtype, device=device)
# 2021-01-04 15:57:56,383 - finished in 30.1909s
# 2021-01-04 15:57:56,385 - ************************************************************
# 2021-01-04 15:57:56,385 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 1
# 	WER 65.07	(DEL: 63.17,	INS: 0.35,	SUB: 1.55)
# 2021-01-04 15:57:56,386 - ************************************************************
# 2021-01-04 15:57:56,387 - ------------------------------------------------------------
# 2021-01-04 15:57:56,388 - [DEV] partition [RECOGNITION] experiment [BW]: 2
# 2021-01-04 15:58:40,879 - finished in 44.4906s
# 2021-01-04 15:58:40,880 - ************************************************************
# 2021-01-04 15:58:40,880 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 2
# 	WER 57.81	(DEL: 54.95,	INS: 0.40,	SUB: 2.46)
# 2021-01-04 15:58:40,881 - ************************************************************
# 2021-01-04 15:58:40,882 - ------------------------------------------------------------
# 2021-01-04 15:58:40,882 - [DEV] partition [RECOGNITION] experiment [BW]: 3
# 2021-01-04 15:59:44,509 - finished in 63.6267s
# 2021-01-04 15:59:44,510 - ************************************************************
# 2021-01-04 15:59:44,511 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 3
# 	WER 55.03	(DEL: 51.83,	INS: 0.40,	SUB: 2.80)
# 2021-01-04 15:59:44,511 - ************************************************************
# 2021-01-04 15:59:44,512 - ------------------------------------------------------------
# 2021-01-04 15:59:44,513 - [DEV] partition [RECOGNITION] experiment [BW]: 4
# 2021-01-04 16:01:06,361 - finished in 81.8481s
# 2021-01-04 16:01:06,362 - ************************************************************
# 2021-01-04 16:01:06,363 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 4
# 	WER 54.50	(DEL: 51.11,	INS: 0.43,	SUB: 2.96)
# 2021-01-04 16:01:06,364 - ************************************************************
# 2021-01-04 16:01:06,364 - ------------------------------------------------------------
# 2021-01-04 16:01:06,365 - [DEV] partition [RECOGNITION] experiment [BW]: 5
# 2021-01-04 16:02:46,767 - finished in 100.4022s
# 2021-01-04 16:02:46,768 - ************************************************************
# 2021-01-04 16:02:46,769 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 5
# 	WER 53.59	(DEL: 50.20,	INS: 0.45,	SUB: 2.94)
# 2021-01-04 16:02:46,770 - ************************************************************
# 2021-01-04 16:02:46,770 - ------------------------------------------------------------
# 2021-01-04 16:02:46,771 - [DEV] partition [RECOGNITION] experiment [BW]: 6
# 2021-01-04 16:04:45,689 - finished in 118.9181s
# 2021-01-04 16:04:45,690 - ************************************************************
# 2021-01-04 16:04:45,691 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 6
# 	WER 53.27	(DEL: 49.85,	INS: 0.45,	SUB: 2.96)
# 2021-01-04 16:04:45,691 - ************************************************************
# 2021-01-04 16:04:45,692 - ------------------------------------------------------------
# 2021-01-04 16:04:45,693 - [DEV] partition [RECOGNITION] experiment [BW]: 7
# 2021-01-04 16:07:03,273 - finished in 137.5800s
# 2021-01-04 16:07:03,274 - ************************************************************
# 2021-01-04 16:07:03,275 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 7
# 	WER 52.95	(DEL: 49.45,	INS: 0.43,	SUB: 3.07)
# 2021-01-04 16:07:03,275 - ************************************************************
# 2021-01-04 16:07:03,277 - ------------------------------------------------------------
# 2021-01-04 16:07:03,279 - [DEV] partition [RECOGNITION] experiment [BW]: 8
# 2021-01-04 16:09:40,417 - finished in 157.1384s
# 2021-01-04 16:09:40,418 - ------------------------------------------------------------
# 2021-01-04 16:09:40,419 - [DEV] partition [RECOGNITION] experiment [BW]: 9
# 2021-01-04 16:12:35,773 - finished in 175.3540s
# 2021-01-04 16:12:35,774 - ************************************************************
# 2021-01-04 16:12:35,775 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 9
# 	WER 52.68	(DEL: 49.19,	INS: 0.43,	SUB: 3.07)
# 2021-01-04 16:12:35,775 - ************************************************************
# 2021-01-04 16:12:35,776 - ------------------------------------------------------------
# 2021-01-04 16:12:35,777 - [DEV] partition [RECOGNITION] experiment [BW]: 10
# 2021-01-04 16:15:50,336 - finished in 194.5590s
# 2021-01-04 16:15:50,337 - ************************************************************
# 2021-01-04 16:15:50,338 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 10
# 	WER 52.60	(DEL: 49.03,	INS: 0.43,	SUB: 3.15)
# 2021-01-04 16:15:50,339 - ************************************************************
# 2021-01-04 16:15:50,339 - ============================================================
# translation
# 2021-01-04 16:16:19,429 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 1 and Alpha: -1
# 	BLEU-4 20.29	(BLEU-1: 46.17,	BLEU-2: 32.92,	BLEU-3: 25.12,	BLEU-4: 20.29)
# 	CHRF 43.81	ROUGE 46.33
# 2021-01-04 16:16:19,430 - ------------------------------------------------------------
# 2021-01-04 16:19:44,145 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 2 and Alpha: -1
# 	BLEU-4 20.54	(BLEU-1: 45.45,	BLEU-2: 32.63,	BLEU-3: 25.19,	BLEU-4: 20.54)
# 	CHRF 43.21	ROUGE 46.29
# 2021-01-04 16:19:44,146 - ------------------------------------------------------------
# 2021-01-04 16:20:44,617 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 2 and Alpha: 1
# 	BLEU-4 20.57	(BLEU-1: 45.63,	BLEU-2: 32.75,	BLEU-3: 25.25,	BLEU-4: 20.57)
# 	CHRF 43.29	ROUGE 46.26
# 2021-01-04 16:20:44,618 - ------------------------------------------------------------
# 2021-01-04 16:21:14,995 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 2 and Alpha: 2
# 	BLEU-4 20.61	(BLEU-1: 45.69,	BLEU-2: 32.80,	BLEU-3: 25.29,	BLEU-4: 20.61)
# 	CHRF 43.31	ROUGE 46.22
# 2021-01-04 16:21:14,996 - ------------------------------------------------------------
# 2021-01-04 16:24:19,636 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 3 and Alpha: 1
# 	BLEU-4 20.67	(BLEU-1: 45.28,	BLEU-2: 32.61,	BLEU-3: 25.26,	BLEU-4: 20.67)
# 	CHRF 43.12	ROUGE 46.50
# 2021-01-04 16:24:19,637 - ------------------------------------------------------------
# 2021-01-04 16:40:35,407 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 7 and Alpha: 2
# 	BLEU-4 20.77	(BLEU-1: 44.88,	BLEU-2: 32.58,	BLEU-3: 25.36,	BLEU-4: 20.77)
# 	CHRF 43.04	ROUGE 46.49
# 2021-01-04 16:40:35,408 - ------------------------------------------------------------
# 2021-01-04 16:41:11,613 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 7 and Alpha: 3
# 	BLEU-4 20.79	(BLEU-1: 45.00,	BLEU-2: 32.66,	BLEU-3: 25.41,	BLEU-4: 20.79)
# 	CHRF 43.07	ROUGE 46.45
# 2021-01-04 16:41:11,614 - ------------------------------------------------------------
# 2021-01-04 16:48:42,485 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 9 and Alpha: 1
# 	BLEU-4 20.82	(BLEU-1: 44.68,	BLEU-2: 32.56,	BLEU-3: 25.40,	BLEU-4: 20.82)
# 	CHRF 42.95	ROUGE 46.66
# 2021-01-04 16:48:42,486 - ------------------------------------------------------------
# 2021-01-04 16:49:21,198 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 9 and Alpha: 2
# 	BLEU-4 20.96	(BLEU-1: 44.88,	BLEU-2: 32.76,	BLEU-3: 25.55,	BLEU-4: 20.96)
# 	CHRF 43.00	ROUGE 46.52
# 2021-01-04 16:49:21,199 - ------------------------------------------------------------
# 2021-01-04 16:49:59,877 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 9 and Alpha: 3
# 	BLEU-4 20.97	(BLEU-1: 44.94,	BLEU-2: 32.80,	BLEU-3: 25.58,	BLEU-4: 20.97)
# 	CHRF 43.01	ROUGE 46.48
# 2021-01-04 16:49:59,878 - ------------------------------------------------------------
# 2021-01-04 16:53:57,795 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 10 and Alpha: 2
# 	BLEU-4 21.07	(BLEU-1: 45.18,	BLEU-2: 32.98,	BLEU-3: 25.71,	BLEU-4: 21.07)
# 	CHRF 43.28	ROUGE 46.75
# 2021-01-04 16:53:57,796 - ------------------------------------------------------------
# 2021-01-04 16:54:37,847 - [DEV] partition [Translation] results:
# 	New Best Translation Beam Size: 10 and Alpha: 3
# 	BLEU-4 21.08	(BLEU-1: 45.24,	BLEU-2: 33.02,	BLEU-3: 25.74,	BLEU-4: 21.08)
# 	CHRF 43.28	ROUGE 46.71
# 2021-01-04 16:54:37,848 - ------------------------------------------------------------
# 2021-01-04 16:55:57,877 - ************************************************************
# 2021-01-04 16:55:57,878 - [DEV] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 10
# 	Best Translation Beam Size: 10 and Alpha: 3
# 	WER 52.60	(DEL: 49.03,	INS: 0.43,	SUB: 3.15)
# 	BLEU-4 21.08	(BLEU-1: 45.24,	BLEU-2: 33.02,	BLEU-3: 25.74,	BLEU-4: 21.08)
# 	CHRF 43.28	ROUGE 46.71
# 2021-01-04 16:55:57,879 - ************************************************************
# 2021-01-04 16:59:57,057 - [TEST] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 10
# 	Best Translation Beam Size: 10 and Alpha: 3
# 	WER 51.02	(DEL: 46.84,	INS: 0.33,	SUB: 3.85)
# 	BLEU-4 20.05	(BLEU-1: 45.04,	BLEU-2: 32.45,	BLEU-3: 24.81,	BLEU-4: 20.05)
# 	CHRF 43.37	ROUGE 46.00
# 2021-01-04 16:59:57,058 - ************************************************************
