# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp 'drive/MyDrive/slt/videos.tar.xz' .
# !tar xvf videos.tar.xz
# Out:
# Streaming output truncated to the last 5000 lines.
# videos/train/29July_2010_Thursday_heute-7742.mp4
# videos/train/21November_2010_Sunday_tagesschau-5674.mp4
# videos/train/05April_2011_Tuesday_tagesschau-6421.mp4
# videos/train/29November_2011_Tuesday_heute-8091.mp4
# videos/train/21April_2010_Wednesday_heute-3116.mp4
# videos/train/15September_2010_Wednesday_heute-2473.mp4
# videos/train/04January_2011_Tuesday_tagesschau-1066.mp4
# videos/train/12May_2010_Wednesday_tagesschau-320.mp4
# videos/train/23February_2011_Wednesday_tagesschau-155.mp4
# videos/train/25July_2010_Sunday_tagesschau-4781.mp4
# videos/train/14December_2010_Tuesday_tagesschau-8461.mp4
# videos/train/09August_2011_Tuesday_tagesschau-2593.mp4
# videos/train/04October_2012_Thursday_tagesschau-4927.mp4
# videos/train/04January_2010_Monday_tagesschau-8548.mp4
# videos/train/14December_2009_Monday_tagesschau-2091.mp4
# videos/train/02October_2012_Tuesday_tagesschau-2856.mp4
# ...

# %%
# !git clone https://github.com/naver/dope.git
# !wget http://download.europe.naverlabs.com/ComputerVision/DOPE_models/DOPE_v1_0_0.pth.tgz
# !mkdir dope/models
# !mv DOPE_v1_0_0.pth.tgz dope/models/DOPE_v1_0_0.pth.tgz
# %cd dope
# !git clone https://github.com/naver/lcrnet-v2-improved-ppi.git;
# %cd ..
# !ls
# Out:
# Cloning into 'dope'...
# remote: Enumerating objects: 20, done.
# remote: Total 20 (delta 0), reused 0 (delta 0), pack-reused 20
# Unpacking objects: 100% (20/20), done.
# --2020-12-24 15:32:02--  http://download.europe.naverlabs.com/ComputerVision/DOPE_models/DOPE_v1_0_0.pth.tgz
# Resolving download.europe.naverlabs.com (download.europe.naverlabs.com)... 217.109.185.194
# Connecting to download.europe.naverlabs.com (download.europe.naverlabs.com)|217.109.185.194|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194655665 (186M) [application/x-gzip]
# Saving to: ‘DOPE_v1_0_0.pth.tgz’
#
# DOPE_v1_0_0.pth.tgz 100%[===================>] 185.64M  2.44MB/s    in 78s
#
# 2020-12-24 15:33:21 (2.39 MB/s) - ‘DOPE_v1_0_0.pth.tgz’ saved [194655665/194655665]
#
# /content/dope
# Cloning into 'lcrnet-v2-improved-ppi'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# ...

# %%
# !cp 'drive/MyDrive/slt/extract_gap_features_via_dope.py' .

# %%
# !python3 extract_gap_features_via_dope.py --video_dir videos/dev --out_dir dev
# !zip -r 'drive/MyDrive/slt/dev_features.zip' dev
# Out:
# Loading model DOPE_v1_0_0
# 100% 519/519 [15:43<00:00,  1.82s/it]
#   adding: dev/ (stored 0%)
#   adding: dev/25April_2010_Sunday_tagesschau-4951.npy (deflated 48%)
#   adding: dev/27May_2011_Friday_tagesschau-8133.npy (deflated 48%)
#   adding: dev/19January_2011_Wednesday_tagesschau-7068.npy (deflated 47%)
#   adding: dev/21November_2009_Saturday_tagesschau-4905.npy (deflated 48%)
#   adding: dev/30November_2010_Tuesday_tagesschau-4617.npy (deflated 48%)
#   adding: dev/02December_2010_Thursday_tagesschau-3636.npy (deflated 47%)
#   adding: dev/23August_2010_Monday_heute-5320.npy (deflated 48%)
#   adding: dev/26April_2010_Monday_tagesschau-7271.npy (deflated 48%)
#   adding: dev/12December_2010_Sunday_tagesschau-5605.npy (deflated 48%)
#   adding: dev/25January_2010_Monday_tagesschau-8305.npy (deflated 47%)
#   adding: dev/07December_2011_Wednesday_tagesschau-5399.npy (deflated 48%)
#   adding: dev/07April_2010_Wednesday_heute-1632.npy (deflated 47%)
# ...

# %%
# !python3 extract_gap_features_via_dope.py --video_dir videos/test --out_dir test
# !zip -r 'drive/MyDrive/slt/test_features.zip' test
# Out:
# Loading model DOPE_v1_0_0
# 100% 642/642 [18:11<00:00,  1.70s/it]
#   adding: test/ (stored 0%)
#   adding: test/24September_2009_Thursday_heute-6081.npy (deflated 47%)
#   adding: test/13November_2009_Friday_tagesschau-8608.npy (deflated 47%)
#   adding: test/15May_2010_Saturday_tagesschau-5659.npy (deflated 48%)
#   adding: test/25November_2009_Wednesday_tagesschau-7668.npy (deflated 48%)
#   adding: test/13April_2010_Tuesday_tagesschau-2314.npy (deflated 48%)
#   adding: test/11September_2009_Friday_tagesschau-8772.npy (deflated 48%)
#   adding: test/28October_2009_Wednesday_tagesschau-4537.npy (deflated 48%)
#   adding: test/14August_2011_Sunday_tagesschau-3230.npy (deflated 48%)
#   adding: test/07October_2010_Thursday_tagesschau-4117.npy (deflated 48%)
#   adding: test/17April_2011_Sunday_tagesschau-2152.npy (deflated 48%)
#   adding: test/25October_2010_Monday_tagesschau-17.npy (deflated 48%)
#   adding: test/20October_2010_Wednesday_tagesschau-8210.npy (deflated 48%)
# ...

# %%
# !python3 extract_gap_features_via_dope.py --video_dir videos/train --out_dir train
# !zip -r 'drive/MyDrive/slt/train_features.zip' train
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: train/29September_2011_Thursday_heute-4223.npy (deflated 48%)
#   adding: train/04July_2009_Saturday_tagesschau-3335.npy (deflated 48%)
#   adding: train/21July_2009_Tuesday_tagesschau-8067.npy (deflated 48%)
#   adding: train/18February_2011_Friday_tagesschau-6834.npy (deflated 48%)
#   adding: train/18September_2010_Saturday_tagesschau-4189.npy (deflated 47%)
#   adding: train/15February_2011_Tuesday_tagesschau-7469.npy (deflated 47%)
#   adding: train/29March_2011_Tuesday_tagesschau-8120.npy (deflated 48%)
#   adding: train/03July_2011_Sunday_tagesschau-1669.npy (deflated 48%)
#   adding: train/04April_2010_Sunday_tagesschau-4575.npy (deflated 48%)
#   adding: train/29August_2009_Saturday_tagesschau-5027.npy (deflated 48%)
#   adding: train/28January_2010_Thursday_heute-2893.npy (deflated 48%)
#   adding: train/23November_2011_Wednesday_heute-2403.npy (deflated 47%)
# ...
